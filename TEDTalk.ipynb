# %% [markdown]
# # Python Pandas
# #### Elizabeth Paperno, Kevin Xiao (PD 7)

# %% [markdown]
# * Pandas is an open source python package used to conduct **data analysis, cleaning, and manipulation.**
# * It is often used in conjunction with other libraries like numpy, matplotlib, scipy, sklearn, and seaborn.
# * It can be used to create Machine Learning models

# %% [markdown]
# ## Dataframes
# * A pandas DataFrame is a two dimensional, size-mutable pandas object.
# * It is similar to a SQL Table, or Excel Spreadsheet.
# * Columns are labelled and can contain varied data types.

# %% [markdown]
# ### Accessing Dataframes

# %%
import pandas as pd #imports library, pd is just convention 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

df = pd.read_csv("weatherHistory.csv") #used to read a csv file (must be in same directory)
display(df.head()) #shows first 5 rows of data
display(df.tail()) #shows last 5 rows of data
print(df.info()) #displays data regarding empty vals
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB
# None

# %% [markdown]
# ### Accessing Specific Data

# %%
print(df["Summary"]) #access specific columns
print(df["Summary"].unique()) #returns list of unique values in the column
# Out:
# 0        Partly Cloudy
# 1        Partly Cloudy
# 2        Mostly Cloudy
# 3        Partly Cloudy
# 4        Mostly Cloudy
#              ...
# 96448    Partly Cloudy
# 96449    Partly Cloudy
# 96450    Partly Cloudy
# 96451    Partly Cloudy
# 96452    Partly Cloudy
# Name: Summary, Length: 96453, dtype: object
# ['Partly Cloudy' 'Mostly Cloudy' 'Overcast' 'Foggy'
#  'Breezy and Mostly Cloudy' 'Clear' 'Breezy and Partly Cloudy'
#  'Breezy and Overcast' 'Humid and Mostly Cloudy' 'Humid and Partly Cloudy'
#  'Windy and Foggy' 'Windy and Overcast' 'Breezy and Foggy'
#  'Windy and Partly Cloudy' 'Breezy' 'Dry and Partly Cloudy'
#  'Windy and Mostly Cloudy' 'Dangerously Windy and Partly Cloudy' 'Dry'
#  'Windy' 'Humid and Overcast' 'Light Rain' 'Drizzle' 'Windy and Dry'
#  'Dry and Mostly Cloudy' 'Breezy and Dry' 'Rain']

# %%
display(df[df["Temperature (C)"]>= 22]) #all days with an temp >= 40
# can use other operations (!=, >, <, <=, >=)
display(df[(df["Temperature (C)"]>= 22) & (df["Humidity"] > 0.5)])
# can also combine statements using & and | operators
# Out:
#                       Formatted Date        Summary Precip Type  \
# 373    2006-04-23 13:00:00.000 +0200  Partly Cloudy        rain
# 374    2006-04-23 14:00:00.000 +0200  Partly Cloudy        rain
# 375    2006-04-23 15:00:00.000 +0200  Partly Cloudy        rain
# 376    2006-04-23 16:00:00.000 +0200  Partly Cloudy        rain
# 395    2006-04-24 11:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96446  2016-09-09 17:00:00.000 +0200  Partly Cloudy        rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 373          22.316667                 22.316667      0.48             7.5348
# 374          22.111111                 22.111111      0.50             6.4561
# 375          22.733333                 22.733333      0.38             1.0143
# 376          22.777778                 22.777778      0.37             5.1842
# 395          22.027778                 22.027778      0.49             4.2826
# ...                ...                       ...       ...                ...
# 96446        30.766667                 29.311111      0.28            14.2163
# 96447        28.838889                 27.850000      0.32            12.2038
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 373                     235.0          11.2700         0.0
# 374                     145.0          11.4471         0.0
# 375                     262.0          10.0464         0.0
# 376                      90.0          10.0464         0.0
# 395                     226.0          11.0285         0.0
# ...                       ...              ...         ...
# 96446                    24.0          15.5526         0.0
# 96447                    21.0          16.1000         0.0
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
#
#        Pressure (millibars)                           Daily Summary
# 373                 1016.27                   Foggy in the morning.
# 374                 1015.96                   Foggy in the morning.
# 375                 1015.34                   Foggy in the morning.
# 376                 1014.70                   Foggy in the morning.
# 395                 1019.86            Partly cloudy until evening.
# ...                     ...                                     ...
# 96446               1013.83  Partly cloudy starting in the morning.
# 96447               1014.07  Partly cloudy starting in the morning.
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
#
# [16188 rows x 12 columns]
#                       Formatted Date        Summary Precip Type  \
# 420    2006-04-25 12:00:00.000 +0200  Partly Cloudy        rain
# 443    2006-04-26 11:00:00.000 +0200  Mostly Cloudy        rain
# 727    2006-08-01 07:00:00.000 +0200  Partly Cloudy        rain
# 728    2006-08-01 08:00:00.000 +0200  Partly Cloudy        rain
# 729    2006-08-01 09:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96424  2016-09-08 19:00:00.000 +0200  Partly Cloudy        rain
# 96425  2016-09-08 20:00:00.000 +0200  Partly Cloudy        rain
# 96438  2016-09-09 09:00:00.000 +0200  Partly Cloudy        rain
# 96439  2016-09-09 10:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 420          22.411111                 22.411111      0.54            11.4471
# 443          22.588889                 22.588889      0.53             4.4275
# 727          22.555556                 22.555556      0.80             1.6100
# 728          24.761111                 24.761111      0.70             3.1717
# 729          27.172222                 28.033333      0.56             1.7388
# ...                ...                       ...       ...                ...
# 96424        24.905556                 24.905556      0.51             0.0000
# 96425        22.366667                 22.366667      0.58             3.3327
# 96438        22.138889                 22.138889      0.65             7.7763
# 96439        22.872222                 22.872222      0.59             6.4239
# 96450        22.038889                 22.038889      0.56             8.9838
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 420                     168.0          11.2056         0.0
# 443                     117.0          10.4006         0.0
# 727                      20.0           9.7566         0.0
# 728                      41.0           9.9015         0.0
# 729                     139.0           9.9820         0.0
# ...                       ...              ...         ...
# 96424                     0.0          16.1000         0.0
# 96425                   135.0          15.5526         0.0
# 96438                    30.0          16.1000         0.0
# 96439                    49.0          16.1000         0.0
# 96450                    30.0          16.1000         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 420                 1020.16             Partly cloudy starting in the morning.
# 443                 1017.19  Mostly cloudy starting overnight continuing un...
# 727                 1011.72                  Partly cloudy starting overnight.
# 728                 1011.86                  Partly cloudy starting overnight.
# 729                 1011.67                  Partly cloudy starting overnight.
# ...                     ...                                                ...
# 96424               1014.14                  Partly cloudy starting overnight.
# 96425               1014.34                  Partly cloudy starting overnight.
# 96438               1015.46             Partly cloudy starting in the morning.
# 96439               1015.65             Partly cloudy starting in the morning.
# 96450               1015.66             Partly cloudy starting in the morning.
#
# [6079 rows x 12 columns]

# %% [markdown]
# ### Built in Operations
#
# * mean = df[“column_name”].mean() #mean of column
# * median = df[“column_name”].median()#median of column
# * std = df[“column_name”].std()#standard deviation
# * max = df[“column_name”].max() #max value in column
# * min = df[“column_name”].min() #min value in column
# * count = df[“column_name”].count()#no. of values in column

# %% [markdown]
# ### Plotting with Matplotlib

# %%
temp = df["Temperature (C)"]

plt.scatter(pd.to_datetime(df["Formatted Date"],utc=True), temp)
plt.title("Weather")
plt.xlabel("Year")
plt.ylabel("Temp (C)")
plt.show()

plt.boxplot(temp, vert=False)
plt.show()

temp_mean = temp.mean()
temp_median = temp.median()

print('Measures of Central Tendency (MoCT)')
print('mean: ', temp_mean)
print('median: ', temp_median)

print("\n")

temp_range = temp.max() - temp.min()
temp_iqr = scipy.stats.iqr(temp)
temp_std = temp.std()

print('Measures of Variability (MoV):')
print('range: ', temp_range)
print('interquartile range: ', temp_iqr)
print('standard deviation: ', temp_std)
# Out:
# Measures of Central Tendency (MoCT)
# mean:  11.93267843751188
# median:  12.0
#
#
# Measures of Variability (MoV):
# range:  61.727777777777774
# interquartile range:  14.150000000000002
# standard deviation:  9.551546320657026

# %% [markdown]
# ## Groupby and Heatmaps
# **Heatmaps** a are two-dimensional representation of data in which values are represented by colors. This allows the viewer of the data to have an easy visual to interpert data.Generally there are two axes that map to a value, and the magnitude of this value is represented by **varying colors**.
#
# **Seaborn** (sns) is generally the library that is used for creating heatmaps in python.

# %%
#creates two new cols with month and year derieved from the datetime format
df['Date'] = pd.to_datetime(df["Formatted Date"],utc=True)
df['Year'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month 

#only includes needed columns
filtered_df = df.loc[:, ['Month', 'Year', 'Temperature (C)']]

groupedMnYr = filtered_df.groupby(['Month', 'Year'], as_index=False).mean() 

groupedMnYr = groupedMnYr.pivot(index='Month', columns='Year', values='Temperature (C)')
display(groupedMnYr)
sns.heatmap(groupedMnYr)
# Out:
# Year       2005       2006       2007       2008       2009       2010  \
# Month
# 1           NaN  -1.677942   4.873708   0.829996  -1.166323  -1.336320
# 2           NaN  -0.065394   4.876356   4.089192   1.837963   1.449363
# 3           NaN   4.559274   8.438881   7.108550   6.683184   6.704786
# 4           NaN  12.635031  12.348071  11.804622  14.559159  12.194329
# 5           NaN  15.650732  17.555220  17.207221  17.857310  16.686522
# 6           NaN  19.354622  21.967623  21.537299  19.644151  20.220340
# 7           NaN  23.588665  23.704562  21.896341  23.169041  23.150918
# 8           NaN  19.478726  23.254391  22.636895  23.009416  21.652163
# 9           NaN  18.167731  14.524020  15.788742  19.391265  15.597693
# 10          NaN  12.844758  10.466271  12.611320  11.461626   8.828980
# 11          NaN   7.137701   3.847801   7.175116   7.578326   8.617685
# 12     0.577778   2.218220  -0.809371   2.982766   2.591682  -0.263538
#
# Year        2011       2012       2013       2014       2015       2016
# Month
# 1       0.164553   1.133901   1.172372   2.775321   2.312858  -0.109670
# 2      -0.158325  -5.136454   3.115344   5.017229   2.435351   6.415493
# 3       5.919213   7.821580   4.584655   9.555346   7.252330   7.436940
# 4      13.378665  12.591088  13.014205  12.978812  11.612160  13.345062
# 5      16.861350  17.159282  17.273454  15.929197  17.113881  16.324836
# 6      21.155301  22.209113  20.125463  19.991929  20.497986  21.309784
# 7      21.562582  24.560260  22.562605  21.905706  23.728920  22.786208
# 8      22.944347  23.675037  23.184595  20.694467  23.802300  21.420296
# 9      20.027423  19.486960  15.443611  17.302647  18.340023  18.467924
# 10     10.286081  12.082176  12.863426  12.724664  10.612761   9.893242
# 11      2.478295   7.908573   7.906103   7.842006   6.688773   5.282662
# 12      2.901986  -0.294728   1.473731   3.190494   2.646438   1.239158
# <Axes: xlabel='Year', ylabel='Month'>

# %% [markdown]
# ### LSTM Model

# %%
# Import the libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
plt.style.use('fivethirtyeight')

# %%
import yfinance as yf
df = yf.download(tickers="MSFT", period="20d", interval="15m", auto_adjust=True)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-02-24 09:30:00-05:00  249.960007  251.000000  249.509995  250.274994
# 2023-02-24 09:45:00-05:00  250.289993  250.289993  249.059998  249.551605
# 2023-02-24 10:00:00-05:00  249.520004  250.130005  249.020004  249.080002
# 2023-02-24 10:15:00-05:00  249.070007  249.690002  248.910004  249.380005
# 2023-02-24 10:30:00-05:00  249.360001  249.429993  248.669998  249.080002
#
#                             Volume
# Datetime
# 2023-02-24 09:30:00-05:00  3255337
# 2023-02-24 09:45:00-05:00  1247295
# 2023-02-24 10:00:00-05:00  1054218
# 2023-02-24 10:15:00-05:00   684138
# 2023-02-24 10:30:00-05:00   725933

# %%
df.shape
# Out:
# (521, 5)

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Closing Price USD($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close' column
data = df.filter(['Close'])
# Convert the datafram to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = math.ceil(len(dataset) * .8) # use about 80% of data for trainng set

training_data_len
# Out:
# 417

# %%
scaler = MinMaxScaler(feature_range=(0,1)) # sets data to values b/w 0 and 1(inclusive)
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.1122988 ],
#        [0.09236364],
#        [0.0793672 ],
#        [0.08763468],
#        [0.0793672 ],
#        [0.0633835 ],
#        [0.06696618],
#        [0.07854049],
#        [0.07688708],
#        [0.08901225],
#        [0.0876372 ],
#        [0.08680797],
#        [0.07110265],
#        [0.06862211],
#        [0.05924997],
#        [0.070273  ],
#        [0.0733044 ],
#        [0.07550909],
#        [0.06933318],
#        [0.0763358 ],
#        [0.06283222],
#        [0.08958034],
#        [0.08308737],
#        [0.07881592],
#        [0.06448564],
#        [0.08294987],
#        [0.14214433],
#        [0.15515171],
#        [0.16413574],
#        [0.1565297 ],
#        [0.12704537],
#        [0.12456231],
#        [0.10830319],
#        [0.10527179],
#        [0.11105874],
#        [0.11463847],
#        [0.1069252 ],
#        [0.10802734],
#        [0.11078331],
#        [0.12511359],
#        [0.13338065],
#        [0.12277097],
#        [0.10802734],
#        [0.12180634],
#        [0.12643607],
#        [0.11271215],
#        [0.10747648],
#        [0.10044905],
#        [0.1030671 ],
#        [0.1038938 ],
#        [0.0956238 ],
#        [0.11023203],
#        [0.09810644],
#        [0.09920899],
#        [0.10720063],
#        [0.09176821],
#        [0.09300827],
#        [0.09962235],
#        [0.10416923],
#        [0.10802734],
#        [0.09190614],
#        [0.09369748],
#        [0.10899197],
#        [0.11175593],
#        [0.11161001],
#        [0.12897169],
#        [0.12897169],
#        [0.13944345],
#        [0.13696333],
#        [0.1328298 ],
#        [0.12621572],
#        [0.11629482],
#        [0.10747648],
#        [0.09810644],
#        [0.09204364],
#        [0.08570542],
#        [0.08515414],
#        [0.08846139],
#        [0.05732071],
#        [0.09369748],
#        [0.03747891],
#        [0.04023488],
#        [0.07578452],
#        [0.05924997],
#        [0.01769219],
#        [0.03224282],
#        [0.04216372],
#        [0.06117881],
#        [0.05594272],
#        [0.04381461],
#        [0.05373803],
#        [0.04436841],
#        [0.04547096],
#        [0.03453834],
#        [0.02645587],
#        [0.02618002],
#        [0.02301112],
#        [0.00881582],
#        [0.01433028],
#        [0.00790375],
#        [0.00881876],
#        [0.00220469],
#        [0.01433028],
#        [0.00110256],
#        [0.02232192],
#        [0.01129888],
#        [0.03830561],
#        [0.03871897],
#        [0.02177106],
#        [0.03940817],
#        [0.03389623],
#        [0.02011723],
#        [0.01543242],
#        [0.0336208 ],
#        [0.02810929],
#        [0.02921142],
#        [0.02893599],
#        [0.03114068],
#        [0.02425118],
#        [0.02576667],
#        [0.05869869],
#        [0.08804803],
#        [0.10031113],
#        [0.12180634],
#        [0.10554722],
#        [0.10582265],
#        [0.11078331],
#        [0.12070421],
#        [0.12538902],
#        [0.13530992],
#        [0.18353349],
#        [0.22514887],
#        [0.22652685],
#        [0.24526652],
#        [0.22804276],
#        [0.21770851],
#        [0.20834141],
#        [0.20792511],
#        [0.20062226],
#        [0.21136986],
#        [0.21247242],
#        [0.21329913],
#        [0.21384746],
#        [0.24085713],
#        [0.25380943],
#        [0.24388853],
#        [0.24223512],
#        [0.23947915],
#        [0.24953797],
#        [0.25353106],
#        [0.25638038],
#        [0.23727446],
#        [0.24058128],
#        [0.23451302],
#        [0.24953797],
#        [0.25132931],
#        [0.31774421],
#        [0.31278313],
#        [0.33207407],
#        [0.3425269 ],
#        [0.37075687],
#        [0.36073463],
#        [0.37671791],
#        [0.36597072],
#        [0.37065259],
#        [0.36321475],
#        [0.35577355],
#        [0.34089283],
#        [0.32490872],
#        [0.33731016],
#        [0.3298698 ],
#        [0.33400333],
#        [0.33124736],
#        [0.32435786],
#        [0.33676182],
#        [0.32510467],
#        [0.33731016],
#        [0.31631619],
#        [0.30910206],
#        [0.2970757 ],
#        [0.30534277],
#        [0.29487059],
#        [0.30231179],
#        [0.29459558],
#        [0.23376621],
#        [0.23726899],
#        [0.24237262],
#        [0.23438099],
#        [0.23672318],
#        [0.23148751],
#        [0.25959638],
#        [0.23479434],
#        [0.23617232],
#        [0.26235235],
#        [0.25739169],
#        [0.25546284],
#        [0.23782279],
#        [0.2443679 ],
#        [0.23203837],
#        [0.22514887],
#        [0.23286508],
#        [0.21839729],
#        [0.21302328],
#        [0.20076018],
#        [0.20640963],
#        [0.20337823],
#        [0.21440126],
#        [0.22046406],
#        [0.19097721],
#        [0.16755273],
#        [0.14523082],
#        [0.1603878 ],
#        [0.16837944],
#        [0.169482  ],
#        [0.19263062],
#        [0.1703087 ],
#        [0.18064296],
#        [0.20723633],
#        [0.17747363],
#        [0.17168627],
#        [0.18408771],
#        [0.1763715 ],
#        [0.17154876],
#        [0.16066323],
#        [0.15101776],
#        [0.15515171],
#        [0.16847321],
#        [0.18739453],
#        [0.18383961],
#        [0.1756823 ],
#        [0.16589932],
#        [0.16810401],
#        [0.20117354],
#        [0.20861432],
#        [0.28715438],
#        [0.32543771],
#        [0.33179822],
#        [0.34061699],
#        [0.3629389 ],
#        [0.33923942],
#        [0.33152321],
#        [0.31967263],
#        [0.32862932],
#        [0.33014481],
#        [0.30341351],
#        [0.32049934],
#        [0.29101291],
#        [0.28715438],
#        [0.27778476],
#        [0.24940299],
#        [0.24030586],
#        [0.21782667],
#        [0.21522797],
#        [0.20833847],
#        [0.21522797],
#        [0.20282695],
#        [0.18739453],
#        [0.15404916],
#        [0.17830034],
#        [0.16700146],
#        [0.09755558],
#        [0.06806831],
#        [0.11946415],
#        [0.08515414],
#        [0.11849951],
#        [0.1664506 ],
#        [0.1336565 ],
#        [0.16631267],
#        [0.15763183],
#        [0.126767  ],
#        [0.11546812],
#        [0.1160194 ],
#        [0.12318433],
#        [0.09976027],
#        [0.10775191],
#        [0.07495781],
#        [0.06421315],
#        [0.04464426],
#        [0.06561552],
#        [0.05070663],
#        [0.05732071],
#        [0.09369748],
#        [0.08074518],
#        [0.07606037],
#        [0.042715  ],
#        [0.06613947],
#        [0.        ],
#        [0.11574355],
#        [0.14068351],
#        [0.13475864],
#        [0.15735641],
#        [0.21605468],
#        [0.2487857 ],
#        [0.26648588],
#        [0.25573827],
#        [0.26593502],
#        [0.25739169],
#        [0.26317905],
#        [0.27254867],
#        [0.24953797],
#        [0.25215602],
#        [0.24278598],
#        [0.26979313],
#        [0.26758843],
#        [0.28605183],
#        [0.29514644],
#        [0.28054073],
#        [0.2896345 ],
#        [0.29266632],
#        [0.25050218],
#        [0.2696552 ],
#        [0.21274785],
#        [0.32077771],
#        [0.29032329],
#        [0.31057886],
#        [0.32601128],
#        [0.3293181 ],
#        [0.3224286 ],
#        [0.33400333],
#        [0.37506449],
#        [0.38856765],
#        [0.38098937],
#        [0.36817499],
#        [0.37396194],
#        [0.37423779],
#        [0.37093096],
#        [0.36018294],
#        [0.35164002],
#        [0.33014481],
#        [0.34160937],
#        [0.33606968],
#        [0.35191587],
#        [0.34998661],
#        [0.34695815],
#        [0.31650373],
#        [0.33248784],
#        [0.35797866],
#        [0.39614677],
#        [0.41805492],
#        [0.44616462],
#        [0.44340866],
#        [0.44588877],
#        [0.45498255],
#        [0.51133652],
#        [0.49191018],
#        [0.48502067],
#        [0.48694994],
#        [0.49328858],
#        [0.43734586],
#        [0.43403903],
#        [0.43148995],
#        [0.43210977],
#        [0.48529652],
#        [0.49411529],
#        [0.46958826],
#        [0.48667409],
#        [0.47785616],
#        [0.51946818],
#        [0.5285628 ],
#        [0.54872922],
#        [0.52580683],
#        [0.53007828],
#        [0.51450794],
#        [0.53104292],
#        [0.50679174],
#        [0.50513832],
#        [0.50403577],
#        [0.49067054],
#        [0.49769796],
#        [0.56053019],
#        [0.55763629],
#        [0.6622193 ],
#        [0.74820015],
#        [0.74131065],
#        [0.73800382],
#        [0.80359117],
#        [0.80800055],
#        [0.79849301],
#        [0.79201728],
#        [0.77835097],
#        [0.80213623],
#        [0.80689884],
#        [0.79008802],
#        [0.79559995],
#        [0.79091472],
#        [0.80364668],
#        [0.81130822],
#        [0.82894491],
#        [0.83032247],
#        [0.82729149],
#        [0.89563565],
#        [0.97334859],
#        [1.        ],
#        [0.99291539],
#        [0.93724767],
#        [0.94661729],
#        [0.90996551],
#        [0.86319646],
#        [0.83170088],
#        [0.86187693],
#        [0.87165948],
#        [0.86917936],
#        [0.90080783],
#        [0.89109087],
#        [0.94358632],
#        [0.93118488],
#        [0.9347541 ],
#        [0.94771985],
#        [0.91440517],
#        [0.88406092],
#        [0.87744727],
#        [0.87910068],
#        [0.89976919],
#        [0.90610699],
#        [0.88268336],
#        [0.91575246],
#        [0.76501013],
#        [0.69873315],
#        [0.72835835],
#        [0.69942194],
#        [0.66249431],
#        [0.67131307],
#        [0.70572189],
#        [0.75233368],
#        [0.7101338 ],
#        [0.68467914],
#        [0.66993551],
#        [0.68757219],
#        [0.68398952],
#        [0.67792672],
#        [0.68343866],
#        [0.68536792],
#        [0.6958401 ],
#        [0.69308413],
#        [0.68922561],
#        [0.68591878],
#        [0.67428938],
#        [0.67958014],
#        [0.67324233],
#        [0.6746199 ],
#        [0.68123439],
#        [0.71705946],
#        [0.75591636],
#        [0.76270073],
#        [0.71184524],
#        [0.66580113],
#        [0.6547781 ],
#        [0.68013436],
#        [0.68867475],
#        [0.6746199 ],
#        [0.65092042],
#        [0.6622193 ],
#        [0.67930765],
#        [0.69749351],
#        [0.6944617 ],
#        [0.70768984],
#        [0.72931205],
#        [0.6980469 ],
#        [0.7027296 ],
#        [0.68237732],
#        [0.69473755],
#        [0.70052449],
#        [0.69418669],
#        [0.71265008],
#        [0.72788991],
#        [0.73745212],
#        [0.75495172],
#        [0.76032574],
#        [0.74075895],
#        [0.7424132 ],
#        [0.7746556 ],
#        [0.84685744],
#        [0.83969293],
#        [0.82370882],
#        [0.8212287 ],
#        [0.82784235],
#        [0.87028192],
#        [0.87221118],
#        [0.83032247],
#        [0.81709769],
#        [0.83666111],
#        [0.84713329],
#        [0.84492818],
#        [0.85016427],
#        [0.85072101],
#        [0.85664084],
#        [0.87386459],
#        [0.90197346],
#        [0.91768172],
#        [0.85319609],
#        [0.83445684],
#        [0.86691706],
#        [0.80689884],
#        [0.71843703],
#        [0.83307844],
#        [0.84823585],
#        [0.86036144],
#        [0.87353912],
#        [0.89343054],
#        [0.93394085],
#        [0.94606644],
#        [0.93325206],
#        [0.92660477],
#        [0.94000364],
#        [0.93228743],
#        [0.94468887],
#        [0.94248376],
#        [0.93173658],
#        [0.90941466],
#        [0.91657917],
#        [0.92470074],
#        [0.89949334],
#        [0.89974396],
#        [0.84176517],
#        [0.81185908],
#        [0.85650291],
#        [0.84961341],
#        [0.84396439],
#        [0.85284287],
#        [0.86614838],
#        [0.86697509]])

# %%
train_data = scaled_data[0:training_data_len, :]
# Split the data into x_train & y_train data sets
x_train = []
y_train = []

for i in range(10, len(train_data)):
  x_train.append(train_data[i-10:i, 0])
  y_train.append(train_data[i, 0])
  if i <= 11:
    print(x_train)
    print(y_train)
# Out:
# [array([0.1122988 , 0.09236364, 0.0793672 , 0.08763468, 0.0793672 ,
#        0.0633835 , 0.06696618, 0.07854049, 0.07688708, 0.08901225])]
# [0.08763720448709122]
# [array([0.1122988 , 0.09236364, 0.0793672 , 0.08763468, 0.0793672 ,
#        0.0633835 , 0.06696618, 0.07854049, 0.07688708, 0.08901225]), array([0.09236364, 0.0793672 , 0.08763468, 0.0793672 , 0.0633835 ,
#        0.06696618, 0.07854049, 0.07688708, 0.08901225, 0.0876372 ])]
# [0.08763720448709122, 0.08680797490108727]

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_train.shape
# Out:
# (407, 1, 10)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(1,x_train.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', run_eagerly=True)

# %%
# Train the model
model.fit(x_train, y_train, batch_size=30, epochs=10) # epoch is the number of iteratons when your entire data set is passed through forward and backward through a neural network
# Out:
# Epoch 1/10
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0993
# Epoch 2/10
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0300
# Epoch 3/10
# 14/14 [==============================] - 1s 46ms/step - loss: 0.0172
# Epoch 4/10
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0061
# Epoch 5/10
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0029
# Epoch 6/10
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0027
# Epoch 7/10
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0026
# Epoch 8/10
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0026
# Epoch 9/10
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0024
# Epoch 10/10
# 14/14 [==============================] - 1s 48ms/step - loss: 0.0022

# %%
test_data = scaled_data[training_data_len - 10 : 521, :]
# Split and create x_test & y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(10, len(test_data)):
  x_test.append(test_data[i-10:i, 0])

x_test = np.array(x_test)
print(x_test)
# Out:
# [[0.94771985 0.91440517 0.88406092 ... 0.88268336 0.91575246 0.76501013]
#  [0.91440517 0.88406092 0.87744727 ... 0.91575246 0.76501013 0.69873315]
#  [0.88406092 0.87744727 0.87910068 ... 0.76501013 0.69873315 0.72835835]
#  ...
#  [0.90941466 0.91657917 0.92470074 ... 0.85650291 0.84961341 0.84396439]
#  [0.91657917 0.92470074 0.89949334 ... 0.84961341 0.84396439 0.85284287]
#  [0.92470074 0.89949334 0.89974396 ... 0.84396439 0.85284287 0.86614838]]

# %%
x_test.shape
# Out:
# (104, 10)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))
x_test.shape
# Out:
# (104, 1, 10)

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 4/4 [==============================] - 0s 22ms/step

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Data', fontsize=18)
plt.ylabel('Closing Price USD($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /var/folders/b6/gn1snq4d5518jn4_hsq5t5500000gn/T/ipykernel_5818/3933017468.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
es = EarlyStopping(monitor = 'val_loss',mode = "min",verbose = 1,patience = 20)
history = model.fit(x_train, y_train, epochs=100, validation_split = 0.2, verbose = 1, callbacks = [es])

plt.plot(history.history['loss'],label = "Training loss")
plt.plot(history.history['val_loss'],label = "Validation loss")
plt.legend()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 2/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 3/100
# 11/11 [==============================] - 1s 67ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 4/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 5/100
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 6/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 7/100
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 8/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 9/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 10/100
# 11/11 [==============================] - 1s 75ms/step - loss: 0.0012 - val_loss: 0.0059
# Epoch 11/100
# 11/11 [==============================] - 1s 94ms/step - loss: 0.0012 - val_loss: 0.0059
# Epoch 12/100
# 11/11 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 13/100
# 11/11 [==============================] - 1s 46ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 14/100
# 11/11 [==============================] - 1s 45ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 15/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0011 - val_loss: 0.0054
# Epoch 16/100
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0011 - val_loss: 0.0049
# Epoch 17/100
# 11/11 [==============================] - 1s 67ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 18/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0010 - val_loss: 0.0050
# Epoch 19/100
# 11/11 [==============================] - 1s 50ms/step - loss: 9.9015e-04 - val_loss: 0.0052
# Epoch 20/100
# 11/11 [==============================] - 0s 39ms/step - loss: 9.6058e-04 - val_loss: 0.0051
# Epoch 21/100
# 11/11 [==============================] - 1s 48ms/step - loss: 9.2887e-04 - val_loss: 0.0046
# Epoch 22/100
# 11/11 [==============================] - 1s 48ms/step - loss: 9.0796e-04 - val_loss: 0.0049
# Epoch 23/100
# 11/11 [==============================] - 0s 43ms/step - loss: 8.8281e-04 - val_loss: 0.0041
# Epoch 24/100
# 11/11 [==============================] - 0s 41ms/step - loss: 8.5087e-04 - val_loss: 0.0043
# Epoch 25/100
# 11/11 [==============================] - 0s 45ms/step - loss: 8.2368e-04 - val_loss: 0.0037
# Epoch 26/100
# 11/11 [==============================] - 1s 51ms/step - loss: 7.9724e-04 - val_loss: 0.0039
# Epoch 27/100
# 11/11 [==============================] - 0s 44ms/step - loss: 7.6724e-04 - val_loss: 0.0038
# Epoch 28/100
# 11/11 [==============================] - 0s 37ms/step - loss: 7.4652e-04 - val_loss: 0.0033
# Epoch 29/100
# 11/11 [==============================] - 0s 41ms/step - loss: 7.1576e-04 - val_loss: 0.0033
# Epoch 30/100
# 11/11 [==============================] - 1s 37ms/step - loss: 7.1151e-04 - val_loss: 0.0036
# Epoch 31/100
# 11/11 [==============================] - 0s 43ms/step - loss: 6.9902e-04 - val_loss: 0.0038
# Epoch 32/100
# 11/11 [==============================] - 0s 37ms/step - loss: 6.5221e-04 - val_loss: 0.0027
# Epoch 33/100
# 11/11 [==============================] - 0s 38ms/step - loss: 6.6562e-04 - val_loss: 0.0030
# Epoch 34/100
# 11/11 [==============================] - 0s 44ms/step - loss: 6.2852e-04 - val_loss: 0.0027
# Epoch 35/100
# 11/11 [==============================] - 0s 40ms/step - loss: 6.1881e-04 - val_loss: 0.0026
# Epoch 36/100
# 11/11 [==============================] - 0s 41ms/step - loss: 6.2306e-04 - val_loss: 0.0029
# Epoch 37/100
# 11/11 [==============================] - 0s 41ms/step - loss: 6.1936e-04 - val_loss: 0.0028
# Epoch 38/100
# 11/11 [==============================] - 0s 38ms/step - loss: 6.1841e-04 - val_loss: 0.0025
# Epoch 39/100
# 11/11 [==============================] - 1s 58ms/step - loss: 5.9190e-04 - val_loss: 0.0031
# Epoch 40/100
# 11/11 [==============================] - 1s 63ms/step - loss: 5.9732e-04 - val_loss: 0.0027
# Epoch 41/100
# 11/11 [==============================] - 0s 41ms/step - loss: 5.8466e-04 - val_loss: 0.0023
# Epoch 42/100
# 11/11 [==============================] - 0s 46ms/step - loss: 5.8197e-04 - val_loss: 0.0024
# Epoch 43/100
# 11/11 [==============================] - 1s 51ms/step - loss: 6.0321e-04 - val_loss: 0.0026
# Epoch 44/100
# 11/11 [==============================] - 0s 45ms/step - loss: 5.7086e-04 - val_loss: 0.0026
# Epoch 45/100
# 11/11 [==============================] - 1s 48ms/step - loss: 5.6799e-04 - val_loss: 0.0026
# Epoch 46/100
# 11/11 [==============================] - 0s 46ms/step - loss: 5.7626e-04 - val_loss: 0.0024
# Epoch 47/100
# 11/11 [==============================] - 0s 42ms/step - loss: 5.6508e-04 - val_loss: 0.0023
# Epoch 48/100
# 11/11 [==============================] - 0s 44ms/step - loss: 5.6155e-04 - val_loss: 0.0023
# Epoch 49/100
# 11/11 [==============================] - 1s 55ms/step - loss: 5.7003e-04 - val_loss: 0.0023
# Epoch 50/100
# 11/11 [==============================] - 1s 49ms/step - loss: 5.7147e-04 - val_loss: 0.0029
# Epoch 51/100
# 11/11 [==============================] - 0s 40ms/step - loss: 5.7063e-04 - val_loss: 0.0021
# Epoch 52/100
# 11/11 [==============================] - 0s 42ms/step - loss: 5.7138e-04 - val_loss: 0.0022
# Epoch 53/100
# 11/11 [==============================] - 0s 42ms/step - loss: 5.4371e-04 - val_loss: 0.0020
# Epoch 54/100
# 11/11 [==============================] - 0s 44ms/step - loss: 5.2866e-04 - val_loss: 0.0021
# Epoch 55/100
# 11/11 [==============================] - 0s 41ms/step - loss: 5.3402e-04 - val_loss: 0.0021
# Epoch 56/100
# 11/11 [==============================] - 0s 39ms/step - loss: 5.2883e-04 - val_loss: 0.0021
# Epoch 57/100
# 11/11 [==============================] - 0s 40ms/step - loss: 5.2053e-04 - val_loss: 0.0023
# Epoch 58/100
# 11/11 [==============================] - 0s 42ms/step - loss: 5.4015e-04 - val_loss: 0.0031
# Epoch 59/100
# 11/11 [==============================] - 0s 41ms/step - loss: 6.3259e-04 - val_loss: 0.0019
# Epoch 60/100
# 11/11 [==============================] - 1s 89ms/step - loss: 5.1891e-04 - val_loss: 0.0020
# Epoch 61/100
# 11/11 [==============================] - 0s 41ms/step - loss: 5.0677e-04 - val_loss: 0.0029
# Epoch 62/100
# 11/11 [==============================] - 0s 41ms/step - loss: 5.5556e-04 - val_loss: 0.0019
# Epoch 63/100
# 11/11 [==============================] - 0s 46ms/step - loss: 4.9487e-04 - val_loss: 0.0024
# Epoch 64/100
# 11/11 [==============================] - 1s 46ms/step - loss: 4.9950e-04 - val_loss: 0.0019
# Epoch 65/100
# 11/11 [==============================] - 1s 59ms/step - loss: 4.9709e-04 - val_loss: 0.0019
# Epoch 66/100
# 11/11 [==============================] - 1s 102ms/step - loss: 5.1254e-04 - val_loss: 0.0027
# Epoch 67/100
# 11/11 [==============================] - 1s 61ms/step - loss: 5.1809e-04 - val_loss: 0.0026
# Epoch 68/100
# 11/11 [==============================] - 1s 52ms/step - loss: 5.2253e-04 - val_loss: 0.0033
# Epoch 69/100
# 11/11 [==============================] - 1s 56ms/step - loss: 6.0908e-04 - val_loss: 0.0019
# Epoch 70/100
# 11/11 [==============================] - 1s 73ms/step - loss: 5.3526e-04 - val_loss: 0.0018
# Epoch 71/100
# 11/11 [==============================] - 1s 55ms/step - loss: 4.8182e-04 - val_loss: 0.0028
# Epoch 72/100
# 11/11 [==============================] - 1s 59ms/step - loss: 4.9180e-04 - val_loss: 0.0017
# Epoch 73/100
# 11/11 [==============================] - 1s 61ms/step - loss: 4.8857e-04 - val_loss: 0.0019
# Epoch 74/100
# 11/11 [==============================] - 1s 50ms/step - loss: 4.8619e-04 - val_loss: 0.0020
# Epoch 75/100
# 11/11 [==============================] - 1s 60ms/step - loss: 4.7937e-04 - val_loss: 0.0022
# Epoch 76/100
# 11/11 [==============================] - 1s 85ms/step - loss: 4.7255e-04 - val_loss: 0.0029
# Epoch 77/100
# 11/11 [==============================] - 1s 56ms/step - loss: 4.6605e-04 - val_loss: 0.0024
# Epoch 78/100
# 11/11 [==============================] - 1s 55ms/step - loss: 5.3377e-04 - val_loss: 0.0034
# Epoch 79/100
# 11/11 [==============================] - 1s 63ms/step - loss: 4.8562e-04 - val_loss: 0.0021
# Epoch 80/100
# 11/11 [==============================] - 0s 43ms/step - loss: 4.7492e-04 - val_loss: 0.0024
# Epoch 81/100
# 11/11 [==============================] - 1s 62ms/step - loss: 4.8359e-04 - val_loss: 0.0025
# Epoch 82/100
# 11/11 [==============================] - 1s 81ms/step - loss: 5.2748e-04 - val_loss: 0.0017
# Epoch 83/100
# 11/11 [==============================] - 1s 83ms/step - loss: 4.9538e-04 - val_loss: 0.0017
# Epoch 84/100
# 11/11 [==============================] - 1s 89ms/step - loss: 5.3165e-04 - val_loss: 0.0021
# Epoch 85/100
# 11/11 [==============================] - 1s 99ms/step - loss: 4.9035e-04 - val_loss: 0.0021
# Epoch 86/100
# 11/11 [==============================] - 1s 47ms/step - loss: 4.7653e-04 - val_loss: 0.0019
# Epoch 87/100
# 11/11 [==============================] - 1s 53ms/step - loss: 4.7971e-04 - val_loss: 0.0020
# Epoch 88/100
# 11/11 [==============================] - 1s 76ms/step - loss: 4.9606e-04 - val_loss: 0.0020
# Epoch 89/100
# 11/11 [==============================] - 1s 62ms/step - loss: 4.7599e-04 - val_loss: 0.0029
# Epoch 90/100
# 11/11 [==============================] - 1s 60ms/step - loss: 4.7962e-04 - val_loss: 0.0036
# Epoch 91/100
# 11/11 [==============================] - 0s 40ms/step - loss: 4.7206e-04 - val_loss: 0.0038
# Epoch 92/100
# 11/11 [==============================] - 0s 45ms/step - loss: 4.6626e-04 - val_loss: 0.0052
# Epoch 93/100
# 11/11 [==============================] - 0s 43ms/step - loss: 4.9235e-04 - val_loss: 0.0024
# Epoch 94/100
# 11/11 [==============================] - 1s 46ms/step - loss: 4.7429e-04 - val_loss: 0.0030
# Epoch 95/100
# 11/11 [==============================] - 0s 41ms/step - loss: 4.5274e-04 - val_loss: 0.0024
# Epoch 96/100
# 11/11 [==============================] - 0s 41ms/step - loss: 4.6245e-04 - val_loss: 0.0023
# Epoch 97/100
# 11/11 [==============================] - 0s 41ms/step - loss: 4.4975e-04 - val_loss: 0.0023
# Epoch 98/100
# 11/11 [==============================] - 1s 70ms/step - loss: 4.5049e-04 - val_loss: 0.0029
# Epoch 99/100
# 11/11 [==============================] - 0s 44ms/step - loss: 4.9415e-04 - val_loss: 0.0031
# Epoch 100/100
# 11/11 [==============================] - 0s 44ms/step - loss: 4.5695e-04 - val_loss: 0.0017
